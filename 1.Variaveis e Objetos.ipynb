# %% [markdown]
# # Práticas em Python
# Variáveis e Objetos

# %%
#Cria variável do tipo inteiro
x = 5
print(x)
#Cria variável do tipo float
y = 9.15
print(y)
#Cria variável do tipo string
m = "Python one"
m = 'Python one'
print(m)
#Cria variável do tipo lógica
w = False  
y = True
print(y)
# Out:
# 5
# 9.15
# Python one
# True

# %%
#calculadora
x = 700
y = 808
z = 900
w = (x + y) * z / 100
print(w)
# Out:
# 13572.0

# %%
print("Today, the class to be very dinamic!")
# Out:
# Today, the class to be very dinamic!

# %%
#exibir texto no console
print("Com base no assunto ensinado, iremos apresentar um print a seguir:")
print(x)
print("Segue o Texto e duas variáveis analisadas anteriormente: ", x ,", ", z)
# Out:
# Com base no assunto ensinado, iremos apresentar um print a seguir:
# 700
# Segue o Texto e duas variáveis analisadas anteriormente:  700 ,  900

# %%
#verificar tipo
print("Realizando um print, onde será analisado o tipo da variável desejada, podemos ver que:\n")
print(type(z))
print(type(w))
# Out:
# Realizando um print, onde será analisado o tipo da variável desejada, podemos ver que:
#
# <class 'int'>
# <class 'float'>

# %%
#entrada de dados
print("Insira o valor desejado: ")
n = input()
#mostra tipo string
print(type(n))

# %%
#entrada de valor com msg separada e junto
print("Insira o valor desejado: ")
n = input()
# ou
n = input("Insira o valor desejado: ")

# %%
#conversão de valores
#para inteiro
valor = input("Insira um valor: ")
print(type(valor))
valor = int(valor)
print(type(valor))

# %%
#para float
valor = input("Insira o valor, conforme desejado: ")
print(type(valor))
valor = float(valor)
print(type(valor))

# %%
# Este texto é um comentário
y = 40  # a partir daqui é um comentário
